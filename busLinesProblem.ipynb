# %%
from BusLinesSolver import Bus_lines_solver

N = 10
M = 4
seed = 42

solver = Bus_lines_solver(N, M, seed_number=seed)

fig = solver.draw_stops_graph()
fig.show()
# Out:
# /tmp/ipykernel_9411/3596158055.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
solver.solve_QUBO()
fig = solver.draw_bus_graph()
fig.show()
# Out:
# /tmp/ipykernel_9411/1175557300.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
