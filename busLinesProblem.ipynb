# %%
from BusLinesSolver import Bus_lines_solver

N = 7
M = 3
p = 5
seed = 42

solver = Bus_lines_solver(N, M, seed_number=seed, numberOfStopsPerLine=p)

fig = solver.draw_stops_graph()
fig.show()
# Out:
# /tmp/ipykernel_10325/1553204896.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
solver.solve_QUBO()
fig = solver.draw_bus_graph()
fig.show()
# Out:
# /tmp/ipykernel_10325/1175557300.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
